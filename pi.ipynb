# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import of the database

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\reclamation\reclamations.csv');

# %%
data.head()
# Out:
#          id last_name first_name  ages  claim_date  \
# 0  20230001       Lee       John  [23]  2022-09-20
# 1  20230002     Brown    Michael  [29]  2022-09-14
# 2  20230003       Doe      David  [21]  2022-10-31
# 3  20230004       Lee       John  [28]  2020-05-17
# 4  20230005       Lee       Anna  [50]  2022-09-21
#
#                                              claim
# 0   I received my clothes and it was missing item.
# 1   I received my clothes and it was missing item.
# 2  I received my clothes and it was late delivery.
# 3    I received my laptop and it was missing item.
# 4      I received my book and it was missing item.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          4000 non-null   int64
#  1   last_name   4000 non-null   object
#  2   first_name  4000 non-null   object
#  3   ages        4000 non-null   object
#  4   claim_date  4000 non-null   object
#  5   claim       4000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 187.6+ KB

# %%
data.describe()
# Out:
#                  id
# count  4.000000e+03
# mean   2.023200e+07
# std    1.154845e+03
# min    2.023000e+07
# 25%    2.023100e+07
# 50%    2.023200e+07
# 75%    2.023300e+07
# max    2.023400e+07

# %%
data.shape
# Out:
# (4000, 6)

# %% [markdown]
# ## Analysis
# I don't have a missing value in my database

# %%
data.isna().sum()
# Out:
# id            0
# last_name     0
# first_name    0
# ages          0
# claim_date    0
# claim         0
# dtype: int64

# %% [markdown]
# ## Analysis
# I don't have a duplicated rows in my database

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#             id last_name first_name  ages  claim_date  \
# 0     20230001       Lee       John  [23]  2022-09-20
# 1     20230002     Brown    Michael  [29]  2022-09-14
# 2     20230003       Doe      David  [21]  2022-10-31
# 3     20230004       Lee       John  [28]  2020-05-17
# 4     20230005       Lee       Anna  [50]  2022-09-21
# ...        ...       ...        ...   ...         ...
# 3995  20233996       Doe       John  [42]  2022-10-03
# 3996  20233997   Johnson      David  [51]  2020-11-07
# 3997  20233998       Doe      David  [51]  2020-11-15
# 3998  20233999       Doe       Anna  [55]  2021-04-02
# 3999  20234000   Johnson    Michael  [40]  2020-10-12
#
#                                                 claim
# 0      I received my clothes and it was missing item.
# 1      I received my clothes and it was missing item.
# 2     I received my clothes and it was late delivery.
# 3       I received my laptop and it was missing item.
# ...

# %% [markdown]
# # Data Preparation

# %%
df=data.copy()

# %%
df
# Out:
#             id last_name first_name  ages  claim_date  \
# 0     20230001       Lee       John  [23]  2022-09-20
# 1     20230002     Brown    Michael  [29]  2022-09-14
# 2     20230003       Doe      David  [21]  2022-10-31
# 3     20230004       Lee       John  [28]  2020-05-17
# 4     20230005       Lee       Anna  [50]  2022-09-21
# ...        ...       ...        ...   ...         ...
# 3995  20233996       Doe       John  [42]  2022-10-03
# 3996  20233997   Johnson      David  [51]  2020-11-07
# 3997  20233998       Doe      David  [51]  2020-11-15
# 3998  20233999       Doe       Anna  [55]  2021-04-02
# 3999  20234000   Johnson    Michael  [40]  2020-10-12
#
#                                                 claim
# 0      I received my clothes and it was missing item.
# 1      I received my clothes and it was missing item.
# 2     I received my clothes and it was late delivery.
# 3       I received my laptop and it was missing item.
# ...

# %%
df["ages"]
# Out:
# 0       [23]
# 1       [29]
# 2       [21]
# 3       [28]
# 4       [50]
#         ...
# 3995    [42]
# 3996    [51]
# 3997    [51]
# 3998    [55]
# 3999    [40]
# Name: ages, Length: 4000, dtype: object

# %%
df["ages"]=df["ages"].str.replace("["," ")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_34120\418055328.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["ages"]=df["ages"].str.replace("["," ")

# %%
df["ages"]
# Out:
# 0        23]
# 1        29]
# 2        21]
# 3        28]
# 4        50]
#         ...
# 3995     42]
# 3996     51]
# 3997     51]
# 3998     55]
# 3999     40]
# Name: ages, Length: 4000, dtype: object

# %%
df["ages"]=df["ages"].str.replace("]"," ")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_34120\1465043606.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["ages"]=df["ages"].str.replace("]"," ")

# %%
df["ages"]
# Out:
# 0        23
# 1        29
# 2        21
# 3        28
# 4        50
#         ...
# 3995     42
# 3996     51
# 3997     51
# 3998     55
# 3999     40
# Name: ages, Length: 4000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          4000 non-null   int64
#  1   last_name   4000 non-null   object
#  2   first_name  4000 non-null   object
#  3   ages        4000 non-null   object
#  4   claim_date  4000 non-null   object
#  5   claim       4000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 187.6+ KB

# %%
df["ages"]=df["ages"].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          4000 non-null   int64
#  1   last_name   4000 non-null   object
#  2   first_name  4000 non-null   object
#  3   ages        4000 non-null   int64
#  4   claim_date  4000 non-null   object
#  5   claim       4000 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 187.6+ KB

# %%
df
# Out:
#             id last_name first_name  ages  claim_date  \
# 0     20230001       Lee       John    23  2022-09-20
# 1     20230002     Brown    Michael    29  2022-09-14
# 2     20230003       Doe      David    21  2022-10-31
# 3     20230004       Lee       John    28  2020-05-17
# 4     20230005       Lee       Anna    50  2022-09-21
# ...        ...       ...        ...   ...         ...
# 3995  20233996       Doe       John    42  2022-10-03
# 3996  20233997   Johnson      David    51  2020-11-07
# 3997  20233998       Doe      David    51  2020-11-15
# 3998  20233999       Doe       Anna    55  2021-04-02
# 3999  20234000   Johnson    Michael    40  2020-10-12
#
#                                                 claim
# 0      I received my clothes and it was missing item.
# 1      I received my clothes and it was missing item.
# 2     I received my clothes and it was late delivery.
# 3       I received my laptop and it was missing item.
# ...

# %%
df=df.drop([ 'id','last_name','first_name'], axis=1)

# %%
df
# Out:
#       ages  claim_date                                            claim
# 0       23  2022-09-20   I received my clothes and it was missing item.
# 1       29  2022-09-14   I received my clothes and it was missing item.
# 2       21  2022-10-31  I received my clothes and it was late delivery.
# 3       28  2020-05-17    I received my laptop and it was missing item.
# 4       50  2022-09-21      I received my book and it was missing item.
# ...    ...         ...                                              ...
# 3995    42  2022-10-03     I received my shoes and it was missing item.
# 3996    51  2020-11-07   I received my laptop and it was wrong product.
# 3997    51  2020-11-15     I received my shoes and it was missing item.
# 3998    55  2021-04-02     I received my phone and it was poor quality.
# 3999    40  2020-10-12   I received my book and it was damaged product.
#
# [4000 rows x 3 columns]

# %%
df["claim_date"]=pd.to_datetime(df["claim_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ages        4000 non-null   int64
#  1   claim_date  4000 non-null   datetime64[ns]
#  2   claim       4000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 93.9+ KB

# %%
from pandas.plotting import scatter_matrix 
scatter_matrix(df,figsize=(9,9))
# Out:
# array([[<Axes: xlabel='ages', ylabel='ages'>]], dtype=object)

# %%
age_counts = df["ages"].value_counts()

# Générer un camembert pour visualiser la distribution des observations par localisation
plt.pie(age_counts.values, labels=age_counts.index, autopct='%1.1f%%')
plt.title('Répartition des observations par Age')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Remarque
# on remarque la base de donnée est equilibré puisque la distribution du colonne age est presque la meme

# %%
fig, ax = plt.subplots()
boxplot = ax.boxplot(df["ages"], showfliers=True)
plt.show()

# %%
plt.hist(df["ages"], bins=100)
plt.show()

# %%
reclamation=df["claim"]

# %%
reclamation
# Out:
# 0        I received my clothes and it was missing item.
# 1        I received my clothes and it was missing item.
# 2       I received my clothes and it was late delivery.
# 3         I received my laptop and it was missing item.
# 4           I received my book and it was missing item.
#                              ...
# 3995       I received my shoes and it was missing item.
# 3996     I received my laptop and it was wrong product.
# 3997       I received my shoes and it was missing item.
# 3998       I received my phone and it was poor quality.
# 3999     I received my book and it was damaged product.
# Name: claim, Length: 4000, dtype: object

# %%
reclamation=reclamation.tolist()

# %%
# !pip install wordcloud

# %%
reclamation
# Out:
# ['I received my clothes and it was missing item.',
#  'I received my clothes and it was missing item.',
#  'I received my clothes and it was late delivery.',
#  'I received my laptop and it was missing item.',
#  'I received my book and it was missing item.',
#  'I received my book and it was late delivery.',
#  'I received my book and it was late delivery.',
#  'I received my book and it was late delivery.',
#  'I received my phone and it was late delivery.',
#  'I received my shoes and it was late delivery.',
#  'I received my book and it was late delivery.',
#  'I received my book and it was late delivery.',
#  'I received my book and it was wrong product.',
#  'I received my book and it was missing item.',
#  'I received my camera and it was poor quality.',
#  'I received my book and it was late delivery.',
#  'I received my clothes and it was poor quality.',
#  'I received my phone and it was wrong product.',
#  'I received my laptop and it was late delivery.',
# ...

# %%
rec =" ".join(reclamation)

# %%
rec
# Out:
# 'I received my clothes and it was missing item. I received my clothes and it was missing item. I received my clothes and it was late delivery. I received my laptop and it was missing item. I received my book and it was missing item. I received my book and it was late delivery. I received my book and it was late delivery. I received my book and it was late delivery. I received my phone and it was late delivery. I received my shoes and it was late delivery. I received my book and it was late delivery. I received my book and it was late delivery. I received my book and it was wrong product. I received my book and it was missing item. I received my camera and it was poor quality. I received my book and it was late delivery. I received my clothes and it was poor quality. I received my phone and it was wrong product. I received my laptop and it was late delivery. I received my book and it was missing item. I received my clothes and it was poor quality. I received my phone and it was damage
# ...

# %%
from wordcloud import WordCloud

plt.figure(figsize=(20,20))
plt.imshow(WordCloud().generate(rec))

# %%
df['claim_date'] = pd.to_datetime(df['claim_date'])

# Create a line plot of the date column
plt.plot(df['claim_date'])

# Add labels and title
plt.xlabel('Date')

plt.title('Line Plot of claim_date')

# Show the plot
plt.show()

# %%
df['claim_date'] = pd.to_datetime(df['claim_date'])
df['value'] = 1
# Create an area plot of the date column
plt.fill_between(df['claim_date'], df['value'], alpha=0.2)

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Area Plot of Date Column')

# Show the plot
plt.show()

# %%
df=df.drop([ 'value'], axis=1)

# %%
df
# Out:
#       ages claim_date                                            claim
# 0       23 2022-09-20   I received my clothes and it was missing item.
# 1       29 2022-09-14   I received my clothes and it was missing item.
# 2       21 2022-10-31  I received my clothes and it was late delivery.
# 3       28 2020-05-17    I received my laptop and it was missing item.
# 4       50 2022-09-21      I received my book and it was missing item.
# ...    ...        ...                                              ...
# 3995    42 2022-10-03     I received my shoes and it was missing item.
# 3996    51 2020-11-07   I received my laptop and it was wrong product.
# 3997    51 2020-11-15     I received my shoes and it was missing item.
# 3998    55 2021-04-02     I received my phone and it was poor quality.
# 3999    40 2020-10-12   I received my book and it was damaged product.
#
# [4000 rows x 3 columns]

# %%
import nltk # Natural Language tool kit 
nltk.download('stopwords')

# You have to download stopwords Package to execute this command
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
# ...

# %%
def message_cleaning(message):
    Test_removed_join_clean = [word for word in message.split() if word.lower() not in stopwords.words('english')]
    return Test_removed_join_clean

# %%
adfcleaned=df['claim'].apply(message_cleaning)

# %%
df['claim']
# Out:
# 0        I received my clothes and it was missing item.
# 1        I received my clothes and it was missing item.
# 2       I received my clothes and it was late delivery.
# 3         I received my laptop and it was missing item.
# 4           I received my book and it was missing item.
#                              ...
# 3995       I received my shoes and it was missing item.
# 3996     I received my laptop and it was wrong product.
# 3997       I received my shoes and it was missing item.
# 3998       I received my phone and it was poor quality.
# 3999     I received my book and it was damaged product.
# Name: claim, Length: 4000, dtype: object

# %%
adfcleaned
# Out:
# 0        [received, clothes, missing, item.]
# 1        [received, clothes, missing, item.]
# 2       [received, clothes, late, delivery.]
# 3         [received, laptop, missing, item.]
# 4           [received, book, missing, item.]
#                         ...
# 3995       [received, shoes, missing, item.]
# 3996     [received, laptop, wrong, product.]
# 3997       [received, shoes, missing, item.]
# 3998       [received, phone, poor, quality.]
# 3999     [received, book, damaged, product.]
# Name: claim, Length: 4000, dtype: object

# %%
df['claim'].unique()
# Out:
# array(['I received my clothes and it was missing item.',
#        'I received my clothes and it was late delivery.',
#        'I received my laptop and it was missing item.',
#        'I received my book and it was missing item.',
#        'I received my book and it was late delivery.',
#        'I received my phone and it was late delivery.',
#        'I received my shoes and it was late delivery.',
#        'I received my book and it was wrong product.',
#        'I received my camera and it was poor quality.',
#        'I received my clothes and it was poor quality.',
#        'I received my phone and it was wrong product.',
#        'I received my laptop and it was late delivery.',
#        'I received my phone and it was damaged product.',
#        'I received my phone and it was missing item.',
#        'I received my clothes and it was damaged product.',
#        'I received my shoes and it was poor quality.',
#        'I received my camera and it was missing item.',
# ...

# %%
p=['missing','item','product','quality','defective','damaged','broken','faulty','poor quality','wrong','incorrect size','size','poor']

# %%
d=['delivery','late','lost package','lost','delivery address','delivery never arrived','arrived','service']

# %%
df['cleanClaim']=adfcleaned

# %%
df
# Out:
#       ages claim_date                                            claim  \
# 0       23 2022-09-20   I received my clothes and it was missing item.
# 1       29 2022-09-14   I received my clothes and it was missing item.
# 2       21 2022-10-31  I received my clothes and it was late delivery.
# 3       28 2020-05-17    I received my laptop and it was missing item.
# 4       50 2022-09-21      I received my book and it was missing item.
# ...    ...        ...                                              ...
# 3995    42 2022-10-03     I received my shoes and it was missing item.
# 3996    51 2020-11-07   I received my laptop and it was wrong product.
# 3997    51 2020-11-15     I received my shoes and it was missing item.
# 3998    55 2021-04-02     I received my phone and it was poor quality.
# 3999    40 2020-10-12   I received my book and it was damaged product.
#
#                                 cleanClaim
# 0      [received, clothes, missing, item.]
# ...

# %%
dc=df.copy()

# %%
dc
# Out:
#       ages claim_date                                            claim  \
# 0       23 2022-09-20   I received my clothes and it was missing item.
# 1       29 2022-09-14   I received my clothes and it was missing item.
# 2       21 2022-10-31  I received my clothes and it was late delivery.
# 3       28 2020-05-17    I received my laptop and it was missing item.
# 4       50 2022-09-21      I received my book and it was missing item.
# ...    ...        ...                                              ...
# 3995    42 2022-10-03     I received my shoes and it was missing item.
# 3996    51 2020-11-07   I received my laptop and it was wrong product.
# 3997    51 2020-11-15     I received my shoes and it was missing item.
# 3998    55 2021-04-02     I received my phone and it was poor quality.
# 3999    40 2020-10-12   I received my book and it was damaged product.
#
#                                 cleanClaim
# 0      [received, clothes, missing, item.]
# ...

# %%
for index, row in df.iterrows():
    for mot in p:
        if mot in row['cleanClaim']:
            # Si un mot spécifique est trouvé, ajouter une valeur dans une autre colonne
            df.at[index, 'type'] = 'product'

# %%
for index, row in df.iterrows():
    for mot in d:
        if mot in row['cleanClaim']:
            # Si un mot spécifique est trouvé, ajouter une valeur dans une autre colonne
            df.at[index, 'type'] = 'delivery'

# %%
df
# Out:
#       ages claim_date                                            claim  \
# 0       23 2022-09-20   I received my clothes and it was missing item.
# 1       29 2022-09-14   I received my clothes and it was missing item.
# 2       21 2022-10-31  I received my clothes and it was late delivery.
# 3       28 2020-05-17    I received my laptop and it was missing item.
# 4       50 2022-09-21      I received my book and it was missing item.
# ...    ...        ...                                              ...
# 3995    42 2022-10-03     I received my shoes and it was missing item.
# 3996    51 2020-11-07   I received my laptop and it was wrong product.
# 3997    51 2020-11-15     I received my shoes and it was missing item.
# 3998    55 2021-04-02     I received my phone and it was poor quality.
# 3999    40 2020-10-12   I received my book and it was damaged product.
#
#                                 cleanClaim      type
# 0      [received, clothes, missing, item.]   product
# ...

# %%
df.isna().sum()
# Out:
# ages          0
# claim_date    0
# claim         0
# cleanClaim    0
# type          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ages        4000 non-null   int64
#  1   claim_date  4000 non-null   datetime64[ns]
#  2   claim       4000 non-null   object
#  3   cleanClaim  4000 non-null   object
#  4   type        4000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 156.4+ KB

# %%
age_counts = df["type"].value_counts()

# Générer un camembert pour visualiser la distribution des observations par localisation
plt.pie(age_counts.values, labels=age_counts.index, autopct='%1.1f%%')
plt.title('Répartition des observations par localisation')
plt.axis('equal')
plt.show()

# %%
# df['type']=df['type'].replace(['product',"delivery"],[1,0])

# %%
df
# Out:
#       ages claim_date                                            claim  \
# 0       23 2022-09-20   I received my clothes and it was missing item.
# 1       29 2022-09-14   I received my clothes and it was missing item.
# 2       21 2022-10-31  I received my clothes and it was late delivery.
# 3       28 2020-05-17    I received my laptop and it was missing item.
# 4       50 2022-09-21      I received my book and it was missing item.
# ...    ...        ...                                              ...
# 3995    42 2022-10-03     I received my shoes and it was missing item.
# 3996    51 2020-11-07   I received my laptop and it was wrong product.
# 3997    51 2020-11-15     I received my shoes and it was missing item.
# 3998    55 2021-04-02     I received my phone and it was poor quality.
# 3999    40 2020-10-12   I received my book and it was damaged product.
#
#                                 cleanClaim      type
# 0      [received, clothes, missing, item.]   product
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ages        4000 non-null   int64
#  1   claim_date  4000 non-null   datetime64[ns]
#  2   claim       4000 non-null   object
#  3   cleanClaim  4000 non-null   object
#  4   type        4000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 156.4+ KB

# %%
dfM=df.copy()

# %%
dfM
# Out:
#       ages claim_date                                            claim  \
# 0       23 2022-09-20   I received my clothes and it was missing item.
# 1       29 2022-09-14   I received my clothes and it was missing item.
# 2       21 2022-10-31  I received my clothes and it was late delivery.
# 3       28 2020-05-17    I received my laptop and it was missing item.
# 4       50 2022-09-21      I received my book and it was missing item.
# ...    ...        ...                                              ...
# 3995    42 2022-10-03     I received my shoes and it was missing item.
# 3996    51 2020-11-07   I received my laptop and it was wrong product.
# 3997    51 2020-11-15     I received my shoes and it was missing item.
# 3998    55 2021-04-02     I received my phone and it was poor quality.
# 3999    40 2020-10-12   I received my book and it was damaged product.
#
#                                 cleanClaim      type
# 0      [received, clothes, missing, item.]   product
# ...

# %%
dfM
# Out:
#       ages claim_date                                            claim  \
# 0       23 2022-09-20   I received my clothes and it was missing item.
# 1       29 2022-09-14   I received my clothes and it was missing item.
# 2       21 2022-10-31  I received my clothes and it was late delivery.
# 3       28 2020-05-17    I received my laptop and it was missing item.
# 4       50 2022-09-21      I received my book and it was missing item.
# ...    ...        ...                                              ...
# 3995    42 2022-10-03     I received my shoes and it was missing item.
# 3996    51 2020-11-07   I received my laptop and it was wrong product.
# 3997    51 2020-11-15     I received my shoes and it was missing item.
# 3998    55 2021-04-02     I received my phone and it was poor quality.
# 3999    40 2020-10-12   I received my book and it was damaged product.
#
#                                 cleanClaim      type
# 0      [received, clothes, missing, item.]   product
# ...

# %%
dfd=dfM.copy()

# %%
dfd=dfd.drop('claim_date', axis=1)

# %%
 dfd['cleanClaim'] = dfd['cleanClaim'].apply(pd.Series).astype(str).agg(', '.join, axis=1)

# # print the data types of each column after conversion
 print(dfd.dtypes)
# Out:
# ages           int64
# claim         object
# cleanClaim    object
# type          object
# dtype: object

# %%
dfd
# Out:
#       ages                                            claim  \
# 0       23   I received my clothes and it was missing item.
# 1       29   I received my clothes and it was missing item.
# 2       21  I received my clothes and it was late delivery.
# 3       28    I received my laptop and it was missing item.
# 4       50      I received my book and it was missing item.
# ...    ...                                              ...
# 3995    42     I received my shoes and it was missing item.
# 3996    51   I received my laptop and it was wrong product.
# 3997    51     I received my shoes and it was missing item.
# 3998    55     I received my phone and it was poor quality.
# 3999    40   I received my book and it was damaged product.
#
#                               cleanClaim      type
# 0      received, clothes, missing, item.   product
# 1      received, clothes, missing, item.   product
# 2     received, clothes, late, delivery.  delivery
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
#dfd['cleanClaim'] = dfd['cleanClaim'].apply(lambda x: ' '.join(x))
X = vectorizer.fit_transform(dfd['claim'] + ' ' + dfd['cleanClaim'])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, dfd['type'], test_size=0.2, random_state=42)
clf = LogisticRegression()
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
# Out:
# 1.0

# %% [markdown]
# #le classificateur Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, dfd['type'], test_size=0.2, random_state=42)
clf = MultinomialNB()
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split
X = dfd.drop(columns=['type'], axis=1)
y = dfd['type']
X_initial_train, X_initial_test, y_initial_train, y_initial_test = train_test_split(X, y, test_size=0.4, random_state=20)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_initial_train, y_initial_train)
y_pred = dtc.predict(X_initial_test)
dtc_acc_ref = accuracy_score(y_initial_test, dtc.predict(X_initial_test))

print(f"Training Accuracy of Decision Tree Classifier is {accuracy_score(y_initial_train, dtc.predict(X_initial_train))}")
print(f"Test Accuracy of Decision Tree Classifier is {clf_acc_ref} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_initial_test, dtc.predict(X_initial_test))}\n")
print(f"Classification Report :- \n {classification_report(y_initial_test, dtc.predict(X_initial_test))}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 3
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 dtc = DecisionTreeClassifier()
# ----> 3 dtc.fit(X_initial_train, y_initial_train)
#       4 y_pred = dtc.predict(X_initial_test)
#       5 dtc_acc_ref = accuracy_score(y_initial_test, dtc.predict(X_initial_test))
#
# File c:\Users\User\anaconda3\lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

rd_clf = RandomForestClassifier(criterion = 'entropy', max_depth = 11, max_features = 'auto', min_samples_leaf = 2, min_samples_split = 3, n_estimators = 130)
rd_clf.fit(X_initial_train, y_initial_train)
y_pred = rd_clf.predict(X_initial_test)
rd_acc_ref = accuracy_score(y_initial_test, rd_clf.predict(X_initial_test))

print(f"Training Accuracy of Random Forest Classifier is {accuracy_score(y_initial_train, rd_clf.predict(X_initial_train))}")
print(f"Test Accuracy of Random Forest Classifier is {clf_acc_ref} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_initial_test, rd_clf.predict(X_initial_test))}\n")
print(f"Classification Report :- \n {classification_report(y_initial_test, rd_clf.predict(X_initial_test))}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[356], line 4
#       1 from sklearn.ensemble import RandomForestClassifier
#       3 rd_clf = RandomForestClassifier(criterion = 'entropy', max_depth = 11, max_features = 'auto', min_samples_leaf = 2, min_samples_split = 3, n_estimators = 130)
# ----> 4 rd_clf.fit(X_initial_train, y_initial_train)
#       5 y_pred = rd_clf.predict(X_initial_test)
#       6 rd_acc_ref = accuracy_score(y_initial_test, rd_clf.predict(X_initial_test))
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:327, in BaseForest.fit(self, X, y, sample_weight)
#     325 if issparse(y):
#     326     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 327 X, y = self._validate_data(
#     328     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     329 )
#     330 if sample_weight is not None:
# ...
